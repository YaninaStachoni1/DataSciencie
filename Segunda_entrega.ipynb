# %% [markdown]
# ## Análisis de datos de Encuesta Mundial de Salud Escolar
#
# ### Grupo 9
# Integrantes:
# - Cruz, Ruth
# - Gabis Leccesi, Luciana
# - Garnica, Rocío
# - Gonzalez Navarro, Sol
# - Palma, Malena Agustina
# - Vidal, Ana
# - Stachoni, Yanina
#
# **Dataset seleccionado:**
# - Resultados encuesta EMSE
# - Origen de datos: https://datos.gob.ar/ar/dataset/salud-base-datos-3deg-encuesta-mundial-salud-escolar-emse-con-resultados-nacionales-argentina
#
# La Encuesta Mundial de Salud Escolar (EMSE) utiliza una metodología estandarizada a nivel mundial para relevar datos sobre aspectos sociodemográficos e indaga sobre conductas relacionadas con el comportamiento alimentario, el consumo de alcohol y otras drogas, la violencia y daños no intencionados, la seguridad vial, la salud mental, el con- sumo de tabaco, la actividad física, los comportamientos sexuales y los factores de protección
#
# **Objetivos:**
# * La EMSE abarca muchas temáticas con más de 70 preguntas. Para nuestro estudio decidimos enforcarnos en temas de violencia y daños no intencionados, persiguiendo los siguientes objetivos:
# * * Detectar patrones en niños y niñas que han sido víctimas de intimidación, considerando relaciones familiares y con amigos, datos físicos y sociodemográficos.
#   * Detectar diferencias en los distintos tipos de intimidación (en escuela, fuera del ámbito escolar, vía internet).
#   * Predecir victimas de intimidación.

# %%
#Importar las librerias necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.impute import SimpleImputer

# %% [markdown]
# -------------
# Para poder centrarnos en el análisis de los datos que nos resultan relevantes, primero analizamos todas las preguntas y seleccionamos aquellas con las que vamos a trabajar, pudiendo ampliar el análisis luego.

# %%
#Leemos Excel creado con el analisis de las preguntas que son de interes
df_conf = pd.read_excel("Analisis Preguntas.xlsx")
print(f"Filas y columnas totales: {df_conf.shape}")
df_conf.head()
# Out:
# Filas y columnas totales: (75, 4)
#   Id Pregunta     Pregunta Relevante Nombre Columna
# 0    texto_q1         Edad        Si           edad
# 1    texto_q2         Sexo        Si           sexo
# 2    texto_q3  Grado o Año        Si          grado
# 3          q4     Estatura        Si         altura
# 4          q5         Peso        Si           peso

# %%
#Armamos configuracion de columnas a cargar del dataset
df_conf = df_conf[df_conf["Relevante"] == "Si"]
print(f"Cantidad de preguntas de interés para el análisis: {df_conf.shape[0]}")
columnas_a_leer = df_conf["Id Pregunta"].values
print(f"Columnas a leer: {columnas_a_leer}")
columnas_nombres = df_conf["Nombre Columna"].values
print(f"Título de las columnas: {columnas_nombres}")
# Out:
# Cantidad de preguntas de interés para el análisis: 41
# Columnas a leer: ['texto_q1' 'texto_q2' 'texto_q3' 'q4' 'q5' 'texto_q6' 'texto_q16'
#  'texto_q17' 'texto_q18' 'texto_q19' 'texto_q22' 'texto_q23' 'texto_q24'
#  'texto_q26' 'texto_q27' 'texto_q28' 'texto_q29' 'texto_q33' 'texto_q34'
#  'texto_q35' 'texto_q39' 'texto_q40' 'texto_q44' 'texto_q45' 'texto_q49'
#  'texto_q51' 'texto_q53' 'texto_q54' 'texto_q55' 'texto_q56' 'texto_q57'
#  'texto_q58' 'texto_q59' 'texto_q60' 'texto_q68' 'texto_q76' 'texto_q80'
#  'texto_q81' 'texto_qnunwtg' 'texto_qnowtg' 'texto_qnobeseg']
# Título de las columnas: ['edad' 'sexo' 'grado' 'altura' 'peso' 'hambre' 'participar_pelea'
#  'cantidad_lesiones' 'tipo_lesion' 'causa_lesion' 'sentir_soledad'
#  'sentir_preocupacion' 'pensar_suicidio' 'intentar_suicidio'
#  'amigos_cercanos' 'edad_cigarrillo' 'dias_fumar' 'padres_fuman'
#  'edad_alcohol' 'dias_tomar_alcohol' 'problemas_alcohol' 'edad_drogas'
#  'relaciones_sexuales' 'edad_relaciones_sexuales' 'dias_act_fisica'
#  'dias_clase_ef' 'dias_falta_clases' 'otros_amables' 'padres_tarea'
#  'padres_atencion' 'padres_tiempo_libre' 'padres_revisar'
#  'padre_educacion' 'madre_educacion' 'intimidacion_internet'
#  'amigos_alcohol' 'sentir_ridiculo' 'padres_expectativas_altas'
#  'bajo_peso' 'sobre_peso' 'obeso']

# %%
#Ahora si importamos el dataset con las columanas preseleccionadas
df = pd.read_csv("EMSE_DatosAbiertos.csv", usecols=columnas_a_leer)
df.shape
# Out:
# (56981, 41)

# %%
#Asignamos los nuevos nombres de columnas
df.columns = columnas_nombres
df.head()
# Out:
#       edad       sexo                                              grado  \
# 0  13 años   Femenino  9no grado nivel Primario/Polimodal o 2do año n...
# 1  13 años   Femenino  9no grado nivel Primario/Polimodal o 2do año n...
# 2  14 años  Masculino  2do año/11vo grado nivel Polimodal o 4to año n...
# 3  16 años  Masculino  9no grado nivel Primario/Polimodal o 2do año n...
# 4  13 años   Femenino  9no grado nivel Primario/Polimodal o 2do año n...
#
#    altura  peso    hambre participar_pelea cantidad_lesiones  \
# 0     NaN   NaN  Rara vez          Ninguna           Ninguna
# 1     NaN   NaN     Nunca          Ninguna           Ninguna
# 2    1.67  56.0     Nunca          Ninguna       2 o 3 veces
# 3    1.73  70.0     Nunca      2 o 3 veces           Ninguna
# 4     NaN   NaN     Nunca          Ninguna      Dato perdido
#
#                                          tipo_lesion  \
# 0  No tuve ninguna lesión seria o grave en los úl...
# 1  No tuve ninguna lesión seria o grave en los úl...
# 2    Tuve un hueso roto o una articulación dislocada
# 3  No tuve ninguna lesión seria o grave en los úl...
# 4                                       Dato perdido
#
#                                         causa_lesion  ... padres_revisar  \
# 0                                       Dato perdido  ...   Dato perdido
# 1  No sufrí ninguna lesión seria o grave durante ...  ...          Nunca
# 2                          Otra cosa causó mi lesión  ...          Nunca
# 3                                       Dato perdido  ...          Nunca
# 4                                       Dato perdido  ...          Nunca
#
#                     padre_educacion        madre_educacion  \
# 0  Terciario/Universitario completo      Primaria completa
# 1             Secundario incompleto  Secundario incompleto
# 2               Secundario completo    Secundario completo
# 3             Secundario incompleto  Secundario incompleto
# 4                 Primaria completa    Primaria incompleta
#
#   intimidacion_internet      amigos_alcohol sentir_ridiculo  \
# 0          Dato perdido  Definitivamente sí    Dato perdido
# 1                    No    Probablemente no           Nunca
# 2                    No  Definitivamente no           Nunca
# 3                    No  Definitivamente sí           Nunca
# 4                    No  Definitivamente no           Nunca
#
#   padres_expectativas_altas     bajo_peso    sobre_peso         obeso
# 0              Dato perdido  Dato perdido  Dato perdido  Dato perdido
# 1             Algunas veces  Dato perdido  Dato perdido  Dato perdido
# 2                   Siempre            No            No            No
# 3                   Siempre            No            No            No
# 4                   Siempre  Dato perdido  Dato perdido  Dato perdido
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Análisis exploratorio de datos

# %%
#Conocemos cantidad de filas y columnas del DataFrame
filas, columnas = df.shape
print(f"El DataFrame tiene {format(filas,',').replace(',','.')} filas y {columnas} columnas")
# Out:
# El DataFrame tiene 56.981 filas y 41 columnas

# %%
#Vemos algunas filas del df
#Las primeras 10 filas
df.head(10)
# Out:
#       edad       sexo                                              grado  \
# 0  13 años   Femenino  9no grado nivel Primario/Polimodal o 2do año n...
# 1  13 años   Femenino  9no grado nivel Primario/Polimodal o 2do año n...
# 2  14 años  Masculino  2do año/11vo grado nivel Polimodal o 4to año n...
# 3  16 años  Masculino  9no grado nivel Primario/Polimodal o 2do año n...
# 4  13 años   Femenino  9no grado nivel Primario/Polimodal o 2do año n...
# 5  13 años  Masculino  9no grado nivel Primario/Polimodal o 2do año n...
# 6  14 años   Femenino  2do año/11vo grado nivel Polimodal o 4to año n...
# 7  12 años   Femenino  2do año/11vo grado nivel Polimodal o 4to año n...
# 8  13 años  Masculino  2do año/11vo grado nivel Polimodal o 4to año n...
# 9  14 años   Femenino  9no grado nivel Primario/Polimodal o 2do año n...
#
#    altura  peso         hambre participar_pelea cantidad_lesiones  \
# 0     NaN   NaN       Rara vez          Ninguna           Ninguna
# 1     NaN   NaN          Nunca          Ninguna           Ninguna
# 2    1.67  56.0          Nunca          Ninguna       2 o 3 veces
# 3    1.73  70.0          Nunca      2 o 3 veces           Ninguna
# 4     NaN   NaN          Nunca          Ninguna      Dato perdido
# 5    1.72  48.0          Nunca            1 vez             1 vez
# 6     NaN   NaN  Algunas veces          Ninguna           Ninguna
# 7     NaN   NaN          Nunca          Ninguna           Ninguna
# 8     NaN   NaN   Casi siempre      2 o 3 veces       2 o 3 veces
# 9     NaN   NaN       Rara vez          Ninguna           Ninguna
#
#                                          tipo_lesion  \
# 0  No tuve ninguna lesión seria o grave en los úl...
# 1  No tuve ninguna lesión seria o grave en los úl...
# 2    Tuve un hueso roto o una articulación dislocada
# 3  No tuve ninguna lesión seria o grave en los úl...
# 4                                       Dato perdido
# 5    Tuve un hueso roto o una articulación dislocada
# 6  No tuve ninguna lesión seria o grave en los úl...
# 7  No tuve ninguna lesión seria o grave en los úl...
# 8                               Me sucedió otra cosa
# 9  No tuve ninguna lesión seria o grave en los úl...
#
#                                         causa_lesion  ... padres_revisar  \
# 0                                       Dato perdido  ...   Dato perdido
# 1  No sufrí ninguna lesión seria o grave durante ...  ...          Nunca
# 2                          Otra cosa causó mi lesión  ...          Nunca
# 3                                       Dato perdido  ...          Nunca
# 4                                       Dato perdido  ...          Nunca
# 5                                             Me caí  ...          Nunca
# 6  No sufrí ninguna lesión seria o grave durante ...  ...       Rara vez
# 7  No sufrí ninguna lesión seria o grave durante ...  ...          Nunca
# 8                                             Me caí  ...  Algunas veces
# 9  No sufrí ninguna lesión seria o grave durante ...  ...          Nunca
#
#                     padre_educacion                     madre_educacion  \
# 0  Terciario/Universitario completo                   Primaria completa
# 1             Secundario incompleto               Secundario incompleto
# 2               Secundario completo                 Secundario completo
# 3             Secundario incompleto               Secundario incompleto
# 4                 Primaria completa                 Primaria incompleta
# 5               Secundario completo  Terciario/Universitario incompleto
# 6               Secundario completo                 Secundario completo
# 7               Secundario completo                 Secundario completo
# 8             Secundario incompleto                 Secundario completo
# 9  Terciario/Universitario completo                 Secundario completo
#
#   intimidacion_internet      amigos_alcohol sentir_ridiculo  \
# 0          Dato perdido  Definitivamente sí    Dato perdido
# 1                    No    Probablemente no           Nunca
# 2                    No  Definitivamente no           Nunca
# 3                    No  Definitivamente sí           Nunca
# 4                    No  Definitivamente no           Nunca
# 5                    No    Probablemente no        Rara vez
# 6                    No  Definitivamente no   Algunas veces
# 7                    No  Definitivamente no   Algunas veces
# 8                    No    Probablemente sí   Algunas veces
# 9                    No    Probablemente sí    Casi siempre
#
#   padres_expectativas_altas     bajo_peso    sobre_peso         obeso
# 0              Dato perdido  Dato perdido  Dato perdido  Dato perdido
# 1             Algunas veces  Dato perdido  Dato perdido  Dato perdido
# 2                   Siempre            No            No            No
# 3                   Siempre            No            No            No
# 4                   Siempre  Dato perdido  Dato perdido  Dato perdido
# 5                   Siempre            No            No            No
# 6             Algunas veces  Dato perdido  Dato perdido  Dato perdido
# 7             Algunas veces  Dato perdido  Dato perdido  Dato perdido
# 8             Algunas veces  Dato perdido  Dato perdido  Dato perdido
# 9             Algunas veces  Dato perdido  Dato perdido  Dato perdido
#
# [10 rows x 41 columns]

# %%
# 3 filas aleatoreas
df.sample(3)
# Out:
#           edad       sexo                                              grado  \
# 561    14 años   Femenino  9no grado nivel Primario/Polimodal o 2do año n...
# 44918  13 años  Masculino  8vo grado nivel Primario/Polimodal  o 1er año ...
# 9521   13 años  Masculino  8vo grado nivel Primario/Polimodal  o 1er año ...
#
#        altura  peso    hambre participar_pelea cantidad_lesiones  \
# 561       NaN   NaN     Nunca            1 vez           Ninguna
# 44918    1.72  89.0  Rara vez          Ninguna           Ninguna
# 9521     1.74  57.0     Nunca          Ninguna             1 vez
#
#                                              tipo_lesion  \
# 561    No tuve ninguna lesión seria o grave en los úl...
# 44918  No tuve ninguna lesión seria o grave en los úl...
# 9521     Tuve un hueso roto o una articulación dislocada
#
#                                             causa_lesion  ... padres_revisar  \
# 561    No sufrí ninguna lesión seria o grave durante ...  ...          Nunca
# 44918  No sufrí ninguna lesión seria o grave durante ...  ...  Algunas veces
# 9521                           Otra cosa causó mi lesión  ...          Nunca
#
#                         padre_educacion                   madre_educacion  \
# 561               Secundario incompleto             Secundario incompleto
# 44918             Secundario incompleto  Terciario/Universitario completo
# 9521   Terciario/Universitario completo  Terciario/Universitario completo
#
#       intimidacion_internet      amigos_alcohol sentir_ridiculo  \
# 561                      No  Definitivamente no           Nunca
# 44918                    No    Probablemente sí           Nunca
# 9521                     No    Probablemente no           Nunca
#
#       padres_expectativas_altas     bajo_peso    sobre_peso         obeso
# 561                     Siempre  Dato perdido  Dato perdido  Dato perdido
# 44918                   Siempre            No            Si            Si
# 9521                      Nunca            No            No            No
#
# [3 rows x 41 columns]

# %%
# Las últimas 5 filas
df.tail(5)
# Out:
#           edad       sexo                                              grado  \
# 56976  16 años  Masculino  3er año/12vo grado nivel Polimodal o 5to año n...
# 56977  16 años  Masculino  3er año/12vo grado nivel Polimodal o 5to año n...
# 56978  16 años  Masculino                                       Dato perdido
# 56979  16 años   Femenino  3er año/12vo grado nivel Polimodal o 5to año n...
# 56980  16 años   Femenino  3er año/12vo grado nivel Polimodal o 5to año n...
#
#        altura  peso         hambre participar_pelea cantidad_lesiones  \
# 56976    1.78  86.0   Casi siempre      4 o 5 veces             1 vez
# 56977     NaN   NaN  Algunas veces          Ninguna           Ninguna
# 56978     NaN   NaN          Nunca          Ninguna           Ninguna
# 56979     NaN   NaN          Nunca          Ninguna             1 vez
# 56980    1.65  56.0       Rara vez          Ninguna      Dato perdido
#
#                                              tipo_lesion  \
# 56976            Recibí un corte, una punzada o puñalada
# 56977  No tuve ninguna lesión seria o grave en los úl...
# 56978  No tuve ninguna lesión seria o grave en los úl...
# 56979    Tuve un hueso roto o una articulación dislocada
# 56980                                       Dato perdido
#
#                                             causa_lesion  ... padres_revisar  \
# 56976  Fui atacado, agredido, abusado o estaba pelean...  ...       Rara vez
# 56977  No sufrí ninguna lesión seria o grave durante ...  ...       Rara vez
# 56978  No sufrí ninguna lesión seria o grave durante ...  ...       Rara vez
# 56979                                             Me caí  ...       Rara vez
# 56980                                       Dato perdido  ...  Algunas veces
#
#                           padre_educacion                   madre_educacion  \
# 56976                   Primaria completa                 Primaria completa
# 56977                 Secundario completo               Secundario completo
# 56978  Terciario/Universitario incompleto             Secundario incompleto
# 56979    Terciario/Universitario completo               Secundario completo
# 56980    Terciario/Universitario completo  Terciario/Universitario completo
#
#       intimidacion_internet      amigos_alcohol sentir_ridiculo  \
# 56976                    No  Definitivamente sí    Casi siempre
# 56977                    No    Probablemente sí    Casi siempre
# 56978                    No    Probablemente sí           Nunca
# 56979                    No    Probablemente no        Rara vez
# 56980                    Si    Probablemente no    Casi siempre
#
#       padres_expectativas_altas     bajo_peso    sobre_peso         obeso
# 56976                  Rara vez            No            Si            No
# 56977             Algunas veces  Dato perdido  Dato perdido  Dato perdido
# 56978                   Siempre  Dato perdido  Dato perdido  Dato perdido
# 56979              Casi siempre  Dato perdido  Dato perdido  Dato perdido
# 56980                  Rara vez            No            No            No
#
# [5 rows x 41 columns]

# %%
#Conocemos tipo de datos y cantidad de no nulos en cada columna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56981 entries, 0 to 56980
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   edad                       56873 non-null  object
#  1   sexo                       56981 non-null  object
#  2   grado                      56981 non-null  object
#  3   altura                     36052 non-null  float64
#  4   peso                       36052 non-null  float64
#  5   hambre                     56981 non-null  object
#  6   participar_pelea           56981 non-null  object
#  7   cantidad_lesiones          56981 non-null  object
#  8   tipo_lesion                56981 non-null  object
#  9   causa_lesion               56981 non-null  object
#  10  sentir_soledad             56981 non-null  object
#  11  sentir_preocupacion        56981 non-null  object
#  12  pensar_suicidio            56981 non-null  object
#  13  intentar_suicidio          56981 non-null  object
#  14  amigos_cercanos            56981 non-null  object
#  15  edad_cigarrillo            56981 non-null  object
#  16  dias_fumar                 56981 non-null  object
#  17  padres_fuman               56981 non-null  object
#  18  edad_alcohol               56981 non-null  object
#  19  dias_tomar_alcohol         56981 non-null  object
#  20  problemas_alcohol          56981 non-null  object
#  21  edad_drogas                56981 non-null  object
#  22  relaciones_sexuales        56981 non-null  object
#  23  edad_relaciones_sexuales   56981 non-null  object
#  24  dias_act_fisica            56981 non-null  object
#  25  dias_clase_ef              56981 non-null  object
#  26  dias_falta_clases          56981 non-null  object
#  27  otros_amables              56981 non-null  object
#  28  padres_tarea               56981 non-null  object
#  29  padres_atencion            56981 non-null  object
#  30  padres_tiempo_libre        56981 non-null  object
#  31  padres_revisar             56981 non-null  object
#  32  padre_educacion            56981 non-null  object
#  33  madre_educacion            56981 non-null  object
#  34  intimidacion_internet      56981 non-null  object
#  35  amigos_alcohol             56981 non-null  object
#  36  sentir_ridiculo            56981 non-null  object
#  37  padres_expectativas_altas  56981 non-null  object
#  38  bajo_peso                  56981 non-null  object
#  39  sobre_peso                 56981 non-null  object
#  40  obeso                      56981 non-null  object
# dtypes: float64(2), object(39)
# memory usage: 17.8+ MB

# %% [markdown]
# **_Vemos que en la mayoría de las columnas categóricas aparenta no haber datos nulos, vamos a evaluar sus opciones para ver si alguna de ellas se corresponde con un valor nulo_**

# %%
print(f"Valores en grado: {df.grado.unique()}")
for columna in df.iloc[:,4:].columns:
    print(f"Valores en {columna}: {df[columna].unique()}")
# Out:
# Valores en grado: ['9no grado nivel Primario/Polimodal o 2do año nivel Secundario'
#  '2do año/11vo grado nivel Polimodal o 4to año nivel Secundario'
#  'Dato perdido'
#  '1er año/10mo grado nivel Polimodal o 3er año nivel Secundario'
#  '3er año/12vo grado nivel Polimodal o 5to año nivel Secundario'
#  '8vo grado nivel Primario/Polimodal  o 1er año nivel Secundario']
# Valores en peso: [ nan  56.  70.  48.  45.  40.  52.  92.  47.  62.  68.  59.  41.  60.
#   53.  51.  58.  32.  54.  44.  49.  75.  50.  55.  61. 122.  73.  82.
#   81.  72.  63.  76.  43.  57.  67.  84.  42.  46.  64.  69.  74.  71.
#  105.  85.  65.  66.  39.  78.  99.  83.  98.  38. 135. 146.  35.  80.
#   95.  86. 100.  97. 158.  88.  36. 120.  90. 163.  94.  79.  87. 103.
#   77.  91.  33. 169. 155.  89.  37. 112. 102. 108.  93.  31. 101. 156.
#  119. 168. 148.  34. 110. 145.  96. 125. 117. 141. 136. 106. 164. 154.
#  160.  30. 149. 174. 153. 140. 150. 175. 157. 130. 132. 172. 104. 114.
#  152.  28. 118. 165. 131. 123. 166. 161. 151. 180. 109. 115. 170. 143.
#  113. 128.  29. 162. 127. 116. 144. 107. 121. 133. 111. 171. 167. 137.
#  147. 178. 126. 124. 187. 142. 129. 138.  27. 139. 159.]
# Valores en hambre: ['Rara vez' 'Nunca' 'Algunas veces' 'Casi siempre' 'Siempre'
#  'Dato perdido']
# Valores en participar_pelea: ['Ninguna' '2 o 3 veces' '1 vez' '4 o 5 veces' '8 o 9 veces'
#  'Dato perdido' '6 o 7 veces' '12 o más veces' '10 u 11 veces']
# Valores en cantidad_lesiones: ['Ninguna' '2 o 3 veces' 'Dato perdido' '1 vez' '4 o 5 veces'
#  '10 u 11 veces' '8 o 9 veces' '6 o 7 veces' '12 o más veces']
# Valores en tipo_lesion: ['No tuve ninguna lesión seria o grave en los últimos 12 meses'
#  'Tuve un hueso roto o una articulación dislocada' 'Dato perdido'
#  'Me sucedió otra cosa'
#  'Sufrí un golpe u otra lesión en la cabeza o el cuello, me desmayé o no podía respirar'
#  'Recibí un corte, una punzada o puñalada' 'Sufrí una quemadura grave'
#  'Recibí una herida con arma de fuego'
#  'Perdí todo o parte de un pie, pierna, mano o brazo']
# Valores en causa_lesion: ['Dato perdido'
#  'No sufrí ninguna lesión seria o grave durante los últimos 12 meses'
#  'Otra cosa causó mi lesión' 'Me caí' 'Algo me cayó encima o me golpeó'
#  'Inhalé o tragué algo que me hizo mal'
#  'Fui atacado, agredido, abusado o estaba peleando con alguien'
#  'Tuve un accidente automovilístico o me atropelló un vehículo a motor'
#  'Estuve en un incendio o me acerqué demasiado a una llama o algo caliente']
# Valores en sentir_soledad: ['Siempre' 'Nunca' 'Rara vez' 'Algunas veces' 'Casi siempre'
#  'Dato perdido']
# Valores en sentir_preocupacion: ['Siempre' 'Nunca' 'Rara vez' 'Algunas veces' 'Casi siempre'
#  'Dato perdido']
# Valores en pensar_suicidio: ['Si' 'No' 'Dato perdido']
# Valores en intentar_suicidio: ['0 veces' '1 vez' '4 o 5 veces' '6 o más veces' '2 o 3 veces'
#  'Dato perdido']
# Valores en amigos_cercanos: ['2' '3 o más' '0' 'Dato perdido' '1']
# Valores en edad_cigarrillo: ['7 años de edad o menos' 'Nunca probé cigarrillos' 'Dato perdido'
#  '8 o 9 años' '14 o 15 años' '12 o 13 años' '10 u 11 años' '16 o 17 años'
#  '18 años o más']
# Valores en dias_fumar: ['Los 30 días' '0 días' 'Dato perdido' '3 a 5 días' '1 o 2 días'
#  '6 a 9 días' '10 a 19 días' '20 a 29 días']
# Valores en padres_fuman: ['Mi padre o mi cuidador' 'Ninguno' 'No sé' 'Ambos'
#  'Mi madre o mi cuidadora' 'Dato perdido']
# Valores en edad_alcohol: ['7 años o menos' 'Nunca tomé alcohol más que unos pocos sorbos'
#  '14 o 15 años' '12 o 13 años' 'Dato perdido' '8 o 9 años' '10 o 11 años'
#  '16 o 17 años' '18 años o más']
# Valores en dias_tomar_alcohol: ['Los 30 días' '0 días' '1 o 2 días' '20 a 29 días' '10 a 19 días'
#  '3 a 5 días' '6 a 9 días' 'Dato perdido']
# Valores en problemas_alcohol: ['10 o más veces' '0 veces' '1 o 2 veces' 'Dato perdido' '3 a 9 veces']
# Valores en edad_drogas: ['Nunca usé Drogas' 'Dato perdido' '14 o 15 años' '12 o 13 años'
#  '16 o 17 años' '7 años o menos' '8 o 9 años' '10 o 11 años'
#  '18 años o más']
# Valores en relaciones_sexuales: ['Si' 'Dato perdido' 'No']
# Valores en edad_relaciones_sexuales: ['11 años o menos' 'Dato perdido' 'Nunca tuve relaciones sexuales'
#  '14 años' '13 años' '12 años' '15 años' '16 o 17 años' '18 años o más']
# Valores en dias_act_fisica: ['7 días' '5 días' '6 días' '4 días' '2 días' '3 días' '1 día' '0 días'
#  'Dato perdido']
# Valores en dias_clase_ef: ['2 días' '0 días' '5 días o más' '4 días' 'Dato perdido' '3 días' '1 día']
# Valores en dias_falta_clases: ['10 días o más' '0 días' '6 a 9 días' '3 a 5 días' 'Dato perdido'
#  '1 o 2 días']
# Valores en otros_amables: ['Nunca' 'Algunas veces' 'Casi siempre' 'Dato perdido' 'Siempre'
#  'Rara vez']
# Valores en padres_tarea: ['Nunca' 'Algunas veces' 'Siempre' 'Casi siempre' 'Rara vez'
#  'Dato perdido']
# Valores en padres_atencion: ['Siempre' 'Dato perdido' 'Casi siempre' 'Nunca' 'Algunas veces'
#  'Rara vez']
# Valores en padres_tiempo_libre: ['Dato perdido' 'Siempre' 'Nunca' 'Casi siempre' 'Rara vez'
#  'Algunas veces']
# Valores en padres_revisar: ['Dato perdido' 'Nunca' 'Rara vez' 'Algunas veces' 'Casi siempre'
#  'Siempre']
# Valores en padre_educacion: ['Terciario/Universitario completo' 'Secundario incompleto'
#  'Secundario completo' 'Primaria completa' 'No sé' 'Dato perdido'
#  'Primaria incompleta' 'Terciario/Universitario incompleto']
# Valores en madre_educacion: ['Primaria completa' 'Secundario incompleto' 'Secundario completo'
#  'Primaria incompleta' 'Terciario/Universitario incompleto' 'No sé'
#  'Dato perdido' 'Terciario/Universitario completo']
# Valores en intimidacion_internet: ['Dato perdido' 'No' 'Si']
# Valores en amigos_alcohol: ['Definitivamente sí' 'Probablemente no' 'Definitivamente no'
#  'Probablemente sí' 'Dato perdido']
# Valores en sentir_ridiculo: ['Dato perdido' 'Nunca' 'Rara vez' 'Algunas veces' 'Casi siempre'
#  'Siempre']
# Valores en padres_expectativas_altas: ['Dato perdido' 'Algunas veces' 'Siempre' 'Rara vez' 'Casi siempre'
#  'Nunca']
# Valores en bajo_peso: ['Dato perdido' 'No' 'Si']
# Valores en sobre_peso: ['Dato perdido' 'No' 'Si']
# Valores en obeso: ['Dato perdido' 'No' 'Si']

# %% [markdown]
# > Vemos que los valores que no tienen información figuran como "Dato perdido", reemplazamos este valor por np.Nan para poder analizar nulos en conjunto y tratarlos según corresponda

# %%
df.replace("Dato perdido", np.nan, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56981 entries, 0 to 56980
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   edad                       56873 non-null  object
#  1   sexo                       56445 non-null  object
#  2   grado                      55920 non-null  object
#  3   altura                     36052 non-null  float64
#  4   peso                       36052 non-null  float64
#  5   hambre                     56482 non-null  object
#  6   participar_pelea           56713 non-null  object
#  7   cantidad_lesiones          51559 non-null  object
#  8   tipo_lesion                52782 non-null  object
#  9   causa_lesion               51790 non-null  object
#  10  sentir_soledad             56615 non-null  object
#  11  sentir_preocupacion        56584 non-null  object
#  12  pensar_suicidio            55628 non-null  object
#  13  intentar_suicidio          56302 non-null  object
#  14  amigos_cercanos            55905 non-null  object
#  15  edad_cigarrillo            55814 non-null  object
#  16  dias_fumar                 56307 non-null  object
#  17  padres_fuman               56143 non-null  object
#  18  edad_alcohol               53338 non-null  object
#  19  dias_tomar_alcohol         54838 non-null  object
#  20  problemas_alcohol          55346 non-null  object
#  21  edad_drogas                54225 non-null  object
#  22  relaciones_sexuales        53992 non-null  object
#  23  edad_relaciones_sexuales   54223 non-null  object
#  24  dias_act_fisica            55551 non-null  object
#  25  dias_clase_ef              55032 non-null  object
#  26  dias_falta_clases          55117 non-null  object
#  27  otros_amables              55422 non-null  object
#  28  padres_tarea               55217 non-null  object
#  29  padres_atencion            54608 non-null  object
#  30  padres_tiempo_libre        55112 non-null  object
#  31  padres_revisar             54997 non-null  object
#  32  padre_educacion            55391 non-null  object
#  33  madre_educacion            55511 non-null  object
#  34  intimidacion_internet      56410 non-null  object
#  35  amigos_alcohol             56073 non-null  object
#  36  sentir_ridiculo            54699 non-null  object
#  37  padres_expectativas_altas  54642 non-null  object
#  38  bajo_peso                  36052 non-null  object
#  39  sobre_peso                 36052 non-null  object
#  40  obeso                      36052 non-null  object
# dtypes: float64(2), object(39)
# memory usage: 17.8+ MB

# %% [markdown]
# >  Notamos que el dato "Edad" figura como `object` en lugar de algún tipo `numérico`. Analizamos sus valores para intentar transformarlo a número.

# %%
df.edad.unique()
# Out:
# array(['13 años', '14 años', '16 años', '12 años', '15 años',
#        '11 años o menos', '17 años', nan, '18 años o más'], dtype=object)

# %% [markdown]
# - Con una expresión regular seleccionamos todos los caracteres entre la `a` y la `z`, incluimos la `ñ`, la `á` y espacios.
# - Reemplazamos todos esos caracteres por vacío `''`

# %%
#Reemplazo de caracteres por ''
df.edad.replace(r'[a-zñá ]', '', regex=True, inplace=True)
#Convertimos ahora la columna a numérica
df.edad = pd.to_numeric(df.edad)
df.edad
# Out:
# 0        13.0
# 1        13.0
# 2        14.0
# 3        16.0
# 4        13.0
#          ...
# 56976    16.0
# 56977    16.0
# 56978    16.0
# 56979    16.0
# 56980    16.0
# Name: edad, Length: 56981, dtype: float64

# %% [markdown]
# ## Análisis de datos nulos y outliers

# %%
#Generamos una tabla con valor y cantidad de nulos por columna, ordenado descendente desde mayor porcentaje
df_info_nulos = pd.DataFrame()
df_info_nulos['Cantidad'] = df.isnull().sum()
df_info_nulos['Porcentaje'] = (df.isnull().mean() * 100).round(2)
df_info_nulos['Tipo de dato'] = df[df_info_nulos.index].dtypes
df_info_nulos.sort_values(by="Porcentaje", ascending=False)
# Out:
#                            Cantidad  Porcentaje Tipo de dato
# obeso                         20929       36.73       object
# sobre_peso                    20929       36.73       object
# altura                        20929       36.73      float64
# peso                          20929       36.73      float64
# bajo_peso                     20929       36.73       object
# cantidad_lesiones              5422        9.52       object
# causa_lesion                   5191        9.11       object
# tipo_lesion                    4199        7.37       object
# edad_alcohol                   3643        6.39       object
# relaciones_sexuales            2989        5.25       object
# edad_drogas                    2756        4.84       object
# edad_relaciones_sexuales       2758        4.84       object
# padres_atencion                2373        4.16       object
# padres_expectativas_altas      2339        4.10       object
# sentir_ridiculo                2282        4.00       object
# dias_tomar_alcohol             2143        3.76       object
# padres_revisar                 1984        3.48       object
# dias_clase_ef                  1949        3.42       object
# padres_tiempo_libre            1869        3.28       object
# dias_falta_clases              1864        3.27       object
# padres_tarea                   1764        3.10       object
# problemas_alcohol              1635        2.87       object
# padre_educacion                1590        2.79       object
# otros_amables                  1559        2.74       object
# madre_educacion                1470        2.58       object
# dias_act_fisica                1430        2.51       object
# pensar_suicidio                1353        2.37       object
# edad_cigarrillo                1167        2.05       object
# amigos_cercanos                1076        1.89       object
# grado                          1061        1.86       object
# amigos_alcohol                  908        1.59       object
# padres_fuman                    838        1.47       object
# intentar_suicidio               679        1.19       object
# dias_fumar                      674        1.18       object
# intimidacion_internet           571        1.00       object
# sexo                            536        0.94       object
# hambre                          499        0.88       object
# sentir_preocupacion             397        0.70       object
# sentir_soledad                  366        0.64       object
# participar_pelea                268        0.47       object
# edad                            108        0.19      float64

# %%
#Analizamos datos estadísticos de las columnas numéricas con datos nulos
datos_numericos = df[["altura","peso","edad"]].describe().T
datos_numericos["moda"] = df[["altura","peso","edad"]].mode().T
datos_numericos.rename(columns={"mean":"media", "50%": "mediana"}, inplace=True)
datos_numericos
# Out:
#           count      media        std   min    25%  mediana   75%     max  \
# altura  36052.0   1.642857   0.096898   1.2   1.57     1.64   1.7    2.03
# peso    36052.0  60.212193  14.723909  27.0  51.00    58.00  66.0  187.00
# edad    56873.0  14.905403   1.358115  11.0  14.00    15.00  16.0   18.00
#
#         moda
# altura   1.6
# peso    60.0
# edad    14.0

# %% [markdown]
# - Para `altura` y `edad` vemos que tienen una desviación estándar baja, por lo tanto los valores se ubican cerca de la media
# - También notamos ques los valores de media, mediana y moda son similares por lo que tendrían una distribución de frecuencias simétrica.
# - Hacemos un gráfico para comprobarlo

# %%
fig = sns.histplot(df, x="altura", kde=True, bins=20)
fig.axvline(datos_numericos.loc["altura"].media, color='r', linestyle='--', label="Media")
fig.axvline(datos_numericos.loc["altura"].mediana, color='g', linestyle='--', label="Mediana")
fig.axvline(datos_numericos.loc["altura"].moda, color='b', linestyle='--', label="Moda")
fig.set_title("Distribución de frecuencias para columna Altura")
fig.legend()

# %%
fig = sns.histplot(df, x="edad", discrete=True)
fig.axvline(datos_numericos.loc["edad"].media, color='r', linestyle='--', label="Media")
fig.axvline(datos_numericos.loc["edad"].mediana, color='g', linestyle='--', label="Mediana")
fig.axvline(datos_numericos.loc["edad"].moda, color='b', linestyle='--', label="Moda")
fig.set_title("Distribución de frecuencias para columna Edad")
fig.legend()

# %% [markdown]
# **_Para los dos casos, rellenamos nulos con el valor de la mediana_**

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy="median")
df.altura = imputer.fit_transform(df[['altura']])
df.edad = imputer.fit_transform(df[['edad']])
df[["altura","edad"]].describe()
# Out:
#              altura          edad
# count  56981.000000  56981.000000
# mean       1.641807     14.905583
# std        0.077087      1.356834
# min        1.200000     11.000000
# 25%        1.610000     14.000000
# 50%        1.640000     15.000000
# 75%        1.670000     16.000000
# max        2.030000     18.000000

# %% [markdown]
# - Analizamos la dispersión y outliers para el caso de la columna `peso`. Ya que al tener una desviación estándar alta, los datos se asume que están dispersos. Con una media, moda y mediana cercanos pero con un sesgo a la derecha ya que la media (60.21) es mayor a la mediana (58)

# %%
#Grafico de bigotes e histograma para evaluar la dispersión
f, (ax_box, ax_hist) = plt.subplots(1,2, figsize=(15, 3), sharex=False, sharey=False)

sns.boxplot(data=df, x="peso", ax=ax_box)

sns.histplot(data=df, x="peso", ax=ax_hist, bins=25, kde=True)

ax_hist.axvline(datos_numericos.loc["peso"].media, color='r', linestyle='--', label="Media")
ax_hist.axvline(datos_numericos.loc["peso"].mediana, color='g', linestyle='--', label="Mediana")
ax_hist.axvline(datos_numericos.loc["peso"].moda, color='b', linestyle='--', label="Moda")
ax_hist.legend()


plt.show()

# %%
#Analizamos cuantos son los outliers y como cambia la descripción estadística de la columna sin ellos
q1, q3 = df["peso"].quantile([.25, .75])
ric = q3 - q1 #rango inter quartil
l_inf = q1 - 1.5 * ric
l_sup = q3 + 1.5 * ric
df_sin_outliers = df[df["peso"].between(l_inf, l_sup)]
print(f"Filas no nulas df original: {df.peso.count()}")
print(f"Filas no nulas sin outliers: {df_sin_outliers.peso.count()}")
print(f"Filas removidas: {df.peso.count() - df_sin_outliers.peso.count()}")
print("Medidas estadísticas originales")
print(df.peso.describe().T)
print("Medidas estadísticas sin outliers")
print(df_sin_outliers.peso.describe().T)
sns.boxplot(data=df_sin_outliers, x="peso")
sns.despine()
# Out:
# Filas no nulas df original: 36052
# Filas no nulas sin outliers: 34878
# Filas removidas: 1174
# Medidas estadísticas originales
# count    36052.000000
# mean        60.212193
# std         14.723909
# min         27.000000
# 25%         51.000000
# 50%         58.000000
# 75%         66.000000
# max        187.000000
# Name: peso, dtype: float64
# Medidas estadísticas sin outliers
# count    34878.000000
# mean        58.526722
# std         10.712567
# min         29.000000
# 25%         50.000000
# 50%         57.000000
# 75%         65.000000
# max         88.000000
# Name: peso, dtype: float64

# %% [markdown]
# > Como el porcentaje de datos removidos es chico (2% --> 1174 filas en 56981 del total de filas), removemos los outliers y rellenamos nulos con la media

# %%
df = df_sin_outliers
imputer = SimpleImputer(missing_values=np.nan, strategy="mean")
df.peso = imputer.fit_transform(df[['peso']])
df[["peso"]].describe()
# Out:
#                peso
# count  34878.000000
# mean      58.526722
# std       10.712567
# min       29.000000
# 25%       50.000000
# 50%       57.000000
# 75%       65.000000
# max       88.000000

# %% [markdown]
# - Como `obeso`, `bajo_peso` y `sobre_peso` están calculados a partir de una fórmula que desconocemos y tienen alto porcentaje en datos nulos eliminaremos esas columnas.

# %%
df.drop(columns=["obeso", "bajo_peso","sobre_peso"], inplace=True)
df.columns
# Out:
# Index(['edad', 'sexo', 'grado', 'altura', 'peso', 'hambre', 'participar_pelea',
#        'cantidad_lesiones', 'tipo_lesion', 'causa_lesion', 'sentir_soledad',
#        'sentir_preocupacion', 'pensar_suicidio', 'intentar_suicidio',
#        'amigos_cercanos', 'edad_cigarrillo', 'dias_fumar', 'padres_fuman',
#        'edad_alcohol', 'dias_tomar_alcohol', 'problemas_alcohol',
#        'edad_drogas', 'relaciones_sexuales', 'edad_relaciones_sexuales',
#        'dias_act_fisica', 'dias_clase_ef', 'dias_falta_clases',
#        'otros_amables', 'padres_tarea', 'padres_atencion',
#        'padres_tiempo_libre', 'padres_revisar', 'padre_educacion',
#        'madre_educacion', 'intimidacion_internet', 'amigos_alcohol',
#        'sentir_ridiculo', 'padres_expectativas_altas'],
#       dtype='object')

# %%
#Volvemos a analizar nulos con los cambios hechos hasta ahora
df_info_nulos = pd.DataFrame()
df_info_nulos['Cantidad'] = df.isnull().sum()
df_info_nulos['Porcentaje'] = (df.isnull().mean() * 100).round(2)
df_info_nulos['Tipo de dato'] = df[df_info_nulos.index].dtypes
df_info_nulos.sort_values(by="Porcentaje", ascending=False)
# Out:
#                            Cantidad  Porcentaje Tipo de dato
# cantidad_lesiones              3245        9.30       object
# causa_lesion                   3152        9.04       object
# tipo_lesion                    2522        7.23       object
# edad_alcohol                   1961        5.62       object
# relaciones_sexuales            1553        4.45       object
# edad_drogas                    1530        4.39       object
# edad_relaciones_sexuales       1497        4.29       object
# padres_expectativas_altas      1195        3.43       object
# dias_tomar_alcohol             1186        3.40       object
# padres_atencion                1134        3.25       object
# sentir_ridiculo                1126        3.23       object
# dias_clase_ef                   956        2.74       object
# padres_revisar                  949        2.72       object
# dias_falta_clases               884        2.53       object
# padres_tiempo_libre             866        2.48       object
# padres_tarea                    834        2.39       object
# padre_educacion                 822        2.36       object
# otros_amables                   735        2.11       object
# problemas_alcohol               735        2.11       object
# madre_educacion                 705        2.02       object
# dias_act_fisica                 680        1.95       object
# pensar_suicidio                 679        1.95       object
# amigos_cercanos                 572        1.64       object
# edad_cigarrillo                 566        1.62       object
# grado                           523        1.50       object
# amigos_alcohol                  408        1.17       object
# padres_fuman                    400        1.15       object
# intentar_suicidio               356        1.02       object
# dias_fumar                      306        0.88       object
# intimidacion_internet           243        0.70       object
# hambre                          204        0.58       object
# sentir_preocupacion             196        0.56       object
# sentir_soledad                  175        0.50       object
# participar_pelea                115        0.33       object
# altura                            0        0.00      float64
# peso                              0        0.00      float64
# sexo                              0        0.00       object
# edad                              0        0.00      float64

# %% [markdown]
# **_Todos los datos faltantes se corresponden con columnas categóricas. Utilizaremos un método de relleno basado en el siguiente valor para las columnas con un porcentaje mayor de datos faltantes y el resto rellenaremos con el `más frecuente`_**

# %%
df.cantidad_lesiones.ffill(inplace=True)
df.causa_lesion.ffill(inplace=True)
df.tipo_lesion.ffill(inplace=True)
df[["cantidad_lesiones","causa_lesion","tipo_lesion"]].isnull().sum()
# Out:
# cantidad_lesiones    0
# causa_lesion         0
# tipo_lesion          0
# dtype: int64

# %%
df_info_nulos['Cantidad'] = df.isnull().sum()
df_info_nulos['Porcentaje'] = (df.isnull().mean() * 100).round(2)
df_info_nulos['Tipo de dato'] = df[df_info_nulos.index].dtypes
df_info_nulos.sort_values(by="Porcentaje", ascending=False)
# Out:
#                            Cantidad  Porcentaje Tipo de dato
# edad_alcohol                   1961        5.62       object
# relaciones_sexuales            1553        4.45       object
# edad_drogas                    1530        4.39       object
# edad_relaciones_sexuales       1497        4.29       object
# padres_expectativas_altas      1195        3.43       object
# dias_tomar_alcohol             1186        3.40       object
# padres_atencion                1134        3.25       object
# sentir_ridiculo                1126        3.23       object
# dias_clase_ef                   956        2.74       object
# padres_revisar                  949        2.72       object
# dias_falta_clases               884        2.53       object
# padres_tiempo_libre             866        2.48       object
# padres_tarea                    834        2.39       object
# padre_educacion                 822        2.36       object
# otros_amables                   735        2.11       object
# problemas_alcohol               735        2.11       object
# madre_educacion                 705        2.02       object
# pensar_suicidio                 679        1.95       object
# dias_act_fisica                 680        1.95       object
# amigos_cercanos                 572        1.64       object
# edad_cigarrillo                 566        1.62       object
# grado                           523        1.50       object
# amigos_alcohol                  408        1.17       object
# padres_fuman                    400        1.15       object
# intentar_suicidio               356        1.02       object
# dias_fumar                      306        0.88       object
# intimidacion_internet           243        0.70       object
# hambre                          204        0.58       object
# sentir_preocupacion             196        0.56       object
# sentir_soledad                  175        0.50       object
# participar_pelea                115        0.33       object
# altura                            0        0.00      float64
# cantidad_lesiones                 0        0.00       object
# peso                              0        0.00      float64
# sexo                              0        0.00       object
# causa_lesion                      0        0.00       object
# tipo_lesion                       0        0.00       object
# edad                              0        0.00      float64

# %%
#Llenamos los nulos con la opción más frecuente.
imputer_frequent = SimpleImputer(missing_values=np.NaN, strategy="most_frequent")

# %%
for columna in df_info_nulos[df_info_nulos["Porcentaje"] > 0].index:
    datos_imputados = imputer_frequent.fit_transform(df[[columna]])
    df[columna] =  datos_imputados[:,0]

# %%
#Chequeamos que no queden nulos
df.isnull().sum()
# Out:
# edad                         0
# sexo                         0
# grado                        0
# altura                       0
# peso                         0
# hambre                       0
# participar_pelea             0
# cantidad_lesiones            0
# tipo_lesion                  0
# causa_lesion                 0
# sentir_soledad               0
# sentir_preocupacion          0
# pensar_suicidio              0
# intentar_suicidio            0
# amigos_cercanos              0
# edad_cigarrillo              0
# dias_fumar                   0
# padres_fuman                 0
# edad_alcohol                 0
# dias_tomar_alcohol           0
# problemas_alcohol            0
# edad_drogas                  0
# relaciones_sexuales          0
# edad_relaciones_sexuales     0
# dias_act_fisica              0
# dias_clase_ef                0
# dias_falta_clases            0
# otros_amables                0
# padres_tarea                 0
# padres_atencion              0
# padres_tiempo_libre          0
# padres_revisar               0
# padre_educacion              0
# madre_educacion              0
# intimidacion_internet        0
# amigos_alcohol               0
# sentir_ridiculo              0
# padres_expectativas_altas    0
# dtype: int64

# %%
#Guardamos nuevo csv con el DataFrame sin datos nulos
df.to_csv("EMSE_DatosAnalisisBullying.csv", index=False)

# %% [markdown]
# ## Transformación de datos categóricos

# %% [markdown]
# ## Gráficos

# %%
#Gráfico de densidad de las columnas numéricas
sns.histplot(df.edad,discrete=True, kde=True)
plt.show()
sns.histplot(df.peso, bins = 10,kde=True)
plt.show()
sns.histplot(df.altura, bins = 10,kde=True)
plt.show()

# %%
#Frecuencia por edad y sexo
fig, axes = plt.subplots(1,2, figsize=(10, 4))

# Trazar el primer gráfico en el primer eje
sns.countplot(data=df, x="sexo", ax=axes[0])
axes[0].set_xlabel('Sexo')
axes[0].set_title('Frecuencia de cada género ')

# Trazar el segundo gráfico en el segundo eje
sns.countplot(data=df, x="edad", hue="sexo", palette="bright",  ax=axes[1])
axes[1].set_xlabel('Edad')
axes[1].set_title('Frecuencia por edad y género')
axes[1].legend()

# Ajustar el diseño de los subgráficos
plt.tight_layout()
